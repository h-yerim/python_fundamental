# %% [markdown]
# 1. 데이터셋 영화 타이틀 데이터 셋
# - movies_title.csv
# 2. titles의 Data Frame 을 만든다.
#
# 3. df 필수 명령 8가지 실행
#
# 4. 전체 영화는 몇개인가?
#
# 5. 가장 빠른 시기에 제작된 영화 2개를 찾아라.
#
# 6. 제목이 "Hamlet"인 영화는 몇개인가?
#
# 7. 제목이 "Treasure Island"는 몇개인가? 제작년도 오름차순으로 나열
#
# 8. 1950년에서 1959냔 사이에 만들어진 영화는 몇개인가?

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# 1. movies_title.csv를 읽어온다

# %%
movies_title = pd.read_csv("c:/hrim/movies_title.csv")
movies_title
# Out:
#                           title  year
# 0                The Rising Son  1990
# 1             Ashes of Kukulcan  2016
# 2       The Thousand Plane Raid  1969
# 3              Crucea de piatra  1993
# 4                        The 86  2015
# ...                         ...   ...
# 215976           Le mouton noir  1922
# 215977      Edge of the Unknown  2015
# 215978                    E yue  2005
# 215979             Lakota Girls  2015
# 215980             The Sting II  1983
#
# [215981 rows x 2 columns]

# %% [markdown]
# 2. 데이터 프레임을 만든다.

# %%
movies_title=pd.DataFrame(movies_title)
movies_title
# Out:
#                           title  year
# 0                The Rising Son  1990
# 1             Ashes of Kukulcan  2016
# 2       The Thousand Plane Raid  1969
# 3              Crucea de piatra  1993
# 4                        The 86  2015
# ...                         ...   ...
# 215976           Le mouton noir  1922
# 215977      Edge of the Unknown  2015
# 215978                    E yue  2005
# 215979             Lakota Girls  2015
# 215980             The Sting II  1983
#
# [215981 rows x 2 columns]

# %% [markdown]
# 3. df 필수 명령 8가지 실행

# %%
movies_title.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1        Ashes of Kukulcan  2016
# 2  The Thousand Plane Raid  1969
# 3         Crucea de piatra  1993
# 4                   The 86  2015

# %%
movies_title.shape
# Out:
# (215981, 2)

# %%
movies_title.columns
# Out:
# Index(['title', 'year'], dtype='object')

# %%
movies_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215981 entries, 0 to 215980
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   title   215981 non-null  object
#  1   year    215981 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 3.3+ MB

# %%
movies_title.tail()
# Out:
#                       title  year
# 215976       Le mouton noir  1922
# 215977  Edge of the Unknown  2015
# 215978                E yue  2005
# 215979         Lakota Girls  2015
# 215980         The Sting II  1983

# %%
movies_title.isnull()
# Out:
#         title   year
# 0       False  False
# 1       False  False
# 2       False  False
# 3       False  False
# 4       False  False
# ...       ...    ...
# 215976  False  False
# 215977  False  False
# 215978  False  False
# 215979  False  False
# 215980  False  False
#
# [215981 rows x 2 columns]

# %%
movies_title["title"].value_counts()
# Out:
# Hamlet                  19
# Macbeth                 14
# Carmen                  14
# The Three Musketeers    12
# Blood Money             11
#                         ..
# Destino das Rosas        1
# Zhivoy bog               1
# Sunday Kinda Love        1
# Vivir para amar          1
# A Boy Called Dad         1
# Name: title, Length: 197575, dtype: int64

# %%
movies_title.describe()
# Out:
#                 year
# count  215981.000000
# mean     1984.553822
# std        29.343957
# min      1894.000000
# 25%      1965.000000
# 50%      1994.000000
# 75%      2010.000000
# max      2024.000000

# %% [markdown]
# 4. 전체 영화 개수

# %%
#중복을 포함한 전체영화 개수
len(movies_title)
# = movies_title.shape[0] #튜플형태라서 인덱스로 접근가능
# = movies_title.count() #전체 행의 개수 (각 열마다)
# = movies_title["title"].count()
# = movies_title.title.count()
# Out:
# 215981

# %% [markdown]
# 5. 가장 빠른 시기에 제작된 영화 2개를 찾아라.

# %%
movies_title["year"].sort_values(ascending=True).head(2)
# = movies_title.sort_values("year").head(2)
# Out:
# 165182    1894
# 85708     1897
# Name: year, dtype: int64

# %%
res=movies_title.sort_values("year").head(2)
res #데이터 프레임임
# Out:
#                                                     title  year
# 165182                                         Miss Jerry  1894
# 85708   Reproduction of the Corbett and Fitzsimmons Fight  1897

# %%
res["title"] #series
# Out:
# 165182                                           Miss Jerry
# 85708     Reproduction of the Corbett and Fitzsimmons Fight
# Name: title, dtype: object

# %%
res["title"].values
# Out:
# array(['Miss Jerry', 'Reproduction of the Corbett and Fitzsimmons Fight'],
#       dtype=object)

# %%
res["title"].values[0]
# Out:
# 'Miss Jerry'

# %%
res["title"].values[1]
# Out:
# 'Reproduction of the Corbett and Fitzsimmons Fight'

# %%
print("가장빠른시기 영화: {}".format(res["title"].values))
# Out:
# 가장빠른시기 영화: ['Miss Jerry' 'Reproduction of the Corbett and Fitzsimmons Fight']

# %% [markdown]
# 6. 제목이 "Hamlet"인 영화는 몇개인가?

# %%
count = 0 
for i in movies_title["title"]:
    if i == "Hamlet":
        count += 1
        
print("제목이 Hamlet인 영화는 ",count,"개입니다.")
# Out:
# 제목이 Hamlet인 영화는  19 개입니다.

# %%
movies_title[movies_title["title"]=="Hamlet"]
# Out:
#          title  year
# 5562    Hamlet  1948
# 26160   Hamlet  2016
# 37373   Hamlet  2015
# 42224   Hamlet  1990
# 43511   Hamlet  1910
# 68239   Hamlet  1954
# 85741   Hamlet  1976
# 87781   Hamlet  1987
# 87971   Hamlet  2000
# 91710   Hamlet  1921
# 114224  Hamlet  1969
# 154627  Hamlet  1913
# 163645  Hamlet  2009
# 169996  Hamlet  1964
# 186988  Hamlet  1996
# 192815  Hamlet  2011
# 195015  Hamlet  1911
# 205821  Hamlet  1973
# 207793  Hamlet  2014

# %%
movies_title[movies_title["title"]=="Hamlet"].shape[0]
# Out:
# 19

# %% [markdown]
# 7. 제목이 "Treasure Island"는 몇개인가? 제작년도 오름차순으로 나열

# %%
count = 0
for i in movies_title["title"]:
    if i=="Treasure Island":
        count +=1
        
print("제목이 Treasure Island 인 영화는 ",count,"개")
print("제작년도 오름차순 정열 \n")
x=movies_title[movies_title["title"]=="Treasure Island"]
print(x.sort_values(by="year"))
# Out:
# 제목이 Treasure Island 인 영화는  8 개
# 제작년도 오름차순 정열
#
#                   title  year
# 191379  Treasure Island  1918
# 47769   Treasure Island  1920
# 192917  Treasure Island  1934
# 90175   Treasure Island  1950
# 104714  Treasure Island  1972
# 103646  Treasure Island  1973
# 190792  Treasure Island  1985
# 166675  Treasure Island  1999

# %% [markdown]
# 8. 1950년에서 1959년 사이에 만들어진 영화는 몇개인가?

# %%
count = 0
for i in movies_title["year"]:
    if (1950<=i)and(i<=1959):
            count += 1

print("1950년에서 1959년 사이에 만들어진 영화는",count,"개입니다.")
# Out:
# 1950년에서 1959년 사이에 만들어진 영화는 12120 개입니다.

# %%
movies_title[(movies_title["year"]>=1950)&(movies_title["year"]<=1959)].shape[0]
# Out:
# 12120

# %% [markdown]
# ### 년도별 영화를 가장 많이 제작된 해 TOP 5
# 1. 년도별 영화건수 누적
# 2. 내림차순 영화건수
# 3. top 5

# %%
movies_title["year"].value_counts().head(5)
# Out:
# 2015    13978
# 2014     8209
# 2013     7664
# 2012     7273
# 2011     6844
# Name: year, dtype: int64

# %%
#선생님 방법(group by)
movies_title.groupby("year")

# %%
list(movies_title.groupby("year"))
# Out:
# [(1894,
#                title  year
#   165182  Miss Jerry  1894),
#  (1897,
#                                                      title  year
#   85708  Reproduction of the Corbett and Fitzsimmons Fight  1897),
#  (1899,
#                                                    title  year
#   115903  Reproduction of the Corbett and Jeffries Fight  1899
#   198354     Sharkey-McCoy Fight Reproduced in 10 Rounds  1899),
#  (1900,
#                                                       title  year
#   12582                                Family Troubles (II)  1900
#   19157   Pierrot's Problem, or How to Make a Fat Wife O...  1900
#   88362                            Trouble in Hogan's Alley  1900
#   170496                              Soldiers of the Cross  1900),
#  (1903,
#                 title  year
#   194264  The Divorce  1903),
#  (1905,
#                      title  year
#   30391            Valsons  1905
#   63463  La malia dell'oro  1905),
#  (1906,
# ...

# %%
list(movies_title.groupby("year"))[1]
# Out:
# (1897,
#                                                     title  year
#  85708  Reproduction of the Corbett and Fitzsimmons Fight  1897)

# %%
movies_title.groupby("year").count() #데이터프레임
# Out:
#       title
# year
# 1894      1
# 1897      1
# 1899      2
# 1900      4
# 1903      1
# ...     ...
# 2019     46
# 2020     36
# 2021      8
# 2022      3
# 2024      2
#
# [124 rows x 1 columns]

# %%
movies_title.groupby("year").count().sort_values(by="title")
# Out:
#       title
# year
# 1894      1
# 1897      1
# 1903      1
# 1905      2
# 2024      2
# ...     ...
# 2011   6844
# 2012   7273
# 2013   7664
# 2014   8209
# 2015  13978
#
# [124 rows x 1 columns]

# %%
movies_title.groupby("year").count()["title"].sort_values()
# Out:
# year
# 1894        1
# 1897        1
# 1903        1
# 1905        2
# 2024        2
#         ...
# 2011     6844
# 2012     7273
# 2013     7664
# 2014     8209
# 2015    13978
# Name: title, Length: 124, dtype: int64

# %%
movies_title.groupby("year").count()["title"].sort_values(ascending=False)
# Out:
# year
# 2015    13978
# 2014     8209
# 2013     7664
# 2012     7273
# 2011     6844
#         ...
# 1905        2
# 1899        2
# 1897        1
# 1903        1
# 1894        1
# Name: title, Length: 124, dtype: int64

# %%
movies_title.groupby("year").count()["title"].sort_values(ascending=False).head(5) #series로 만들어서 한거임
# Out:
# year
# 2015    13978
# 2014     8209
# 2013     7664
# 2012     7273
# 2011     6844
# Name: title, dtype: int64

# %%
movies_title.groupby("year").count().sort_values("title") #dataframe
# Out:
#       title
# year
# 1894      1
# 1897      1
# 1903      1
# 1905      2
# 2024      2
# ...     ...
# 2011   6844
# 2012   7273
# 2013   7664
# 2014   8209
# 2015  13978
#
# [124 rows x 1 columns]

# %%
movies_title.groupby("year").count().sort_values("title",ascending=False).head(5)
# Out:
#       title
# year
# 2015  13978
# 2014   8209
# 2013   7664
# 2012   7273
# 2011   6844
