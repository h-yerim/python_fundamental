# %%
import pandas as pd
url="https://movie.naver.com/movie/point/af/list.nhn"
df=pd.read_html(url);df
# Out:
# [         번호                                                감상평  \
#  0  17573148  체르노빌 1986  별점 - 총 10점 중10  체르노빌의 아픈 실화를 담아내며 당...
#  1  17573147  체르노빌 1986  별점 - 총 10점 중10  엄청난 재난과 진한 드라마 그리고 ...
#  2  17573146  체르노빌 1986  별점 - 총 10점 중10  실화라서 더 무섭고 마음이 아팠아요...
#  3  17573145  체르노빌 1986  별점 - 총 10점 중10  이 모든게 실화라는 것이 알고 있음...
#  4  17573144  월드 인베이젼  별점 - 총 10점 중10  스토리 라인은 간단하지만 잘 만들면 다...
#  5  17573143  콰이어트 플레이스 2  별점 - 총 10점 중10  생존물 좋아하는 난 꿀잼!!! ...
#  6  17573142                          미드나이트  별점 - 총 10점 중10  신고
#  7  17573141  컨저링 3: 악마가 시켰다  별점 - 총 10점 중1  걍 노잼이다 보지마라 ㅈㄴ ...
#  8  17573140                   인 더 하이츠  별점 - 총 10점 중8  잘 봤어요 신고
#  9  17573139  웬디  별점 - 총 10점 중10  재밌게 봤음. 일단 웬디를 주인공으로 내세운 점...
#
#               글쓴이·날짜
#  0  yom9****21.07.01
#  1  kite****21.07.01
#  2  abou****21.07.01
#  3  sord****21.07.01
#  4  78tn****21.07.01
#  5  kpq8****21.07.01
#  6  wjde****21.07.01
#  7  inhs****21.07.01
#  8  kkyu****21.07.01
#  9  lsb8****21.07.01  ]

# %%
type(df)
# Out:
# list

# %%
df[0] #사이트가 html 테이블형태로 데이터가 구현되어있으면 이렇게 데이터프레임으로 불러올수있다.
# Out:
#          번호                                                감상평  \
# 0  17573146  체르노빌 1986  별점 - 총 10점 중10  실화라서 더 무섭고 마음이 아팠아요...
# 1  17573145  체르노빌 1986  별점 - 총 10점 중10  이 모든게 실화라는 것이 알고 있음...
# 2  17573144  월드 인베이젼  별점 - 총 10점 중10  스토리 라인은 간단하지만 잘 만들면 다...
# 3  17573143  콰이어트 플레이스 2  별점 - 총 10점 중10  생존물 좋아하는 난 꿀잼!!! ...
# 4  17573142                          미드나이트  별점 - 총 10점 중10  신고
# 5  17573141  컨저링 3: 악마가 시켰다  별점 - 총 10점 중1  걍 노잼이다 보지마라 ㅈㄴ ...
# 6  17573140                   인 더 하이츠  별점 - 총 10점 중8  잘 봤어요 신고
# 7  17573139  웬디  별점 - 총 10점 중10  재밌게 봤음. 일단 웬디를 주인공으로 내세운 점...
# 8  17573138  발신제한  별점 - 총 10점 중10  폭탄소재영화를 긴장감있게 잘연출함 조우진연기...
# 9  17573137  빛나는 순간  별점 - 총 10점 중9  고두심 배우님, 지현우 배우님 연기에 감탄...
#
#              글쓴이·날짜
# 0  abou****21.07.01
# 1  sord****21.07.01
# 2  78tn****21.07.01
# 3  kpq8****21.07.01
# 4  wjde****21.07.01
# 5  inhs****21.07.01
# 6  kkyu****21.07.01
# 7  lsb8****21.07.01
# 8  swat****21.07.01
# 9  jean****21.07.01

# %%
url="https://www.kca.go.kr/odr/pg/pi/osPgItemExamW.do"
df=pd.read_html(url)

# %%
df[0]
# Out:
#     번호                                                 제목      출처   조회수
# 0  662                  방문판매를 통해 구매한 건강기능식품의 청약철회를 거절한 경우   섬유식품팀    14
# 1  661  전자상거래를 통해 의류 구입 후 반품했더니 7일 이내 반품 완료되지 않았다는 이유로...   섬유식품팀  1196
# 2  660         전자상거래에서 의류 구입 후, 구성품(비닐) 누락을 이유로 반품 거절한 경우   섬유식품팀  1086
# 3  659    SNS 통해 의류구입 후 40분 지나 청약철회 요청하니 해외배송비 공제 안내하는 경우   섬유식품팀   895
# 4  658                         청약 철회 요구한 상품의 회수 지연시 대응 방안  주택공산품팀   785
# 5  657                            할부결제한 고가의 시계를 배송지연하는 경우  주택공산품팀   803
# 6  656                          광고와 규격이 다른 매트리스의 반품 가능 여부  주택공산품팀   686
# 7  655                   노조 파업으로 A/S 지연된 정수기 렌탈서비스의 보상 여부  주택공산품팀   427
# 8  654                       입주 4년 된 아파트 발코니 배수관의 빗물 역류현상  주택공산품팀   370
# 9  653                          아파트 분양 카탈로그 기재 사항의 미시공 책임  주택공산품팀   151
